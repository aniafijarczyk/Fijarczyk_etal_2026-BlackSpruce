# %%
import pandas as pd
import itertools
from scipy.stats import spearmanr
from scipy.stats import pearsonr
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # DATA

# %%
cols = ['sample', 'SITE_ID', 'offset', 'marker', 'trait', 
       'POP_SITE', 'POP_ID', 'SET', 'mean', 'sd', 'n', 'group', 'train_group']

# %%
df1 = pd.read_csv("01_garden_compare_separate.tsv", sep="\t", header=0)
df1["train_group"] = "combined"
df1 = df1[cols].reset_index(drop=True)
df1["climate"] = "var3"
df1.head()
# Out:
#     sample SITE_ID    offset    marker   trait POP_SITE  POP_ID   SET  \
# 0  2209_PR      PR  0.020352  1000var5  Height  2209_PR    2209  TEST
# 1   325_PR      PR  0.100402  1000var5  Height   325_PR     325  TEST
# 2  4351_PR      PR  0.095057  1000var5  Height  4351_PR    4351  TEST
# 3  4420_PR      PR  0.032337  1000var5  Height  4420_PR    4420  TEST
# 4  6805_PR      PR  0.090211  1000var5  Height  6805_PR    6805  TEST
#
#           mean          sd    n    group train_group climate
# 0   980.525258  302.158899  4.0     West    combined    var3
# 1  1239.891145  121.743290  8.0  Central    combined    var3
# 2  1423.598605   68.068593  4.0  Central    combined    var3
# 3   678.153897  154.272486  7.0     West    combined    var3
# 4  1353.974749  229.855027  7.0     East    combined    var3

# %%
df2 = pd.read_csv("08_garden_clusters.tsv", sep="\t", header=0)
df2 = df2[cols].reset_index(drop=True)
df2["climate"] = "var3"
df2.head()
# Out:
#     sample SITE_ID    offset    marker   trait POP_SITE  POP_ID   SET  \
# 0  2209_PR      PR  0.047933  1000var5  Height  2209_PR    2209  TEST
# 1   325_PR      PR  0.080800  1000var5  Height   325_PR     325  TEST
# 2  4351_PR      PR  0.104527  1000var5  Height  4351_PR    4351  TEST
# 3  4420_PR      PR  0.069182  1000var5  Height  4420_PR    4420  TEST
# 4  6805_PR      PR  0.067058  1000var5  Height  6805_PR    6805  TEST
#
#           mean          sd    n    group train_group climate
# 0   980.525258  302.158899  4.0     West     Central    var3
# 1  1239.891145  121.743290  8.0  Central     Central    var3
# 2  1423.598605   68.068593  4.0  Central     Central    var3
# 3   678.153897  154.272486  7.0     West     Central    var3
# 4  1353.974749  229.855027  7.0     East     Central    var3

# %%
df3 = pd.read_csv("../951_garden_plot/01_garden_compare_separate.tsv", sep="\t", header=0)
df3["train_group"] = "combined"
df3 = df3[df3["marker"] == "1000"].reset_index(drop=True)
df3 = df3[cols].reset_index(drop=True)
df3["climate"] = "PC3"
df3.head()
# Out:
#     sample SITE_ID    offset marker   trait POP_SITE  POP_ID   SET  \
# 0  2209_PR      PR  0.085200   1000  Height  2209_PR    2209  TEST
# 1   325_PR      PR  0.098895   1000  Height   325_PR     325  TEST
# 2  4351_PR      PR  0.039102   1000  Height  4351_PR    4351  TEST
# 3  4420_PR      PR  0.022427   1000  Height  4420_PR    4420  TEST
# 4  6805_PR      PR  0.072544   1000  Height  6805_PR    6805  TEST
#
#           mean          sd    n    group train_group climate
# 0   980.525258  302.158899  4.0     West    combined     PC3
# 1  1239.891145  121.743290  8.0  Central    combined     PC3
# 2  1423.598605   68.068593  4.0  Central    combined     PC3
# 3   678.153897  154.272486  7.0     West    combined     PC3
# 4  1353.974749  229.855027  7.0     East    combined     PC3

# %%
df4 = pd.read_csv("../996_garden_plot_clusters/08_garden_clusters.tsv", sep="\t", header=0)
df4 = df4[cols].reset_index(drop=True)
df4["climate"] = "PC3"
df4.head()
# Out:
#     sample SITE_ID    offset  marker   trait POP_SITE  POP_ID   SET  \
# 0  2209_PR      PR  0.065431    1000  Height  2209_PR    2209  TEST
# 1   325_PR      PR  0.045821    1000  Height   325_PR     325  TEST
# 2  4351_PR      PR  0.040407    1000  Height  4351_PR    4351  TEST
# 3  4420_PR      PR  0.035705    1000  Height  4420_PR    4420  TEST
# 4  6805_PR      PR  0.029996    1000  Height  6805_PR    6805  TEST
#
#           mean          sd    n    group train_group climate
# 0   980.525258  302.158899  4.0     West     Central     PC3
# 1  1239.891145  121.743290  8.0  Central     Central     PC3
# 2  1423.598605   68.068593  4.0  Central     Central     PC3
# 3   678.153897  154.272486  7.0     West     Central     PC3
# 4  1353.974749  229.855027  7.0     East     Central     PC3

# %%
df = pd.concat([df1, df2, df3, df4], ignore_index=True)
df = df[df["SET"] == "TEST"].reset_index(drop=True)
df["train_clim"] = df.apply(lambda x: x["train_group"] + "_" + x["climate"], axis=1)
print(df.shape)
df.head()
# Out:
# (11274, 15)
#     sample SITE_ID    offset    marker   trait POP_SITE  POP_ID   SET  \
# 0  2209_PR      PR  0.020352  1000var5  Height  2209_PR    2209  TEST
# 1   325_PR      PR  0.100402  1000var5  Height   325_PR     325  TEST
# 2  4351_PR      PR  0.095057  1000var5  Height  4351_PR    4351  TEST
# 3  4420_PR      PR  0.032337  1000var5  Height  4420_PR    4420  TEST
# 4  6805_PR      PR  0.090211  1000var5  Height  6805_PR    6805  TEST
#
#           mean          sd    n    group train_group climate     train_clim
# 0   980.525258  302.158899  4.0     West    combined    var3  combined_var3
# 1  1239.891145  121.743290  8.0  Central    combined    var3  combined_var3
# 2  1423.598605   68.068593  4.0  Central    combined    var3  combined_var3
# 3   678.153897  154.272486  7.0     West    combined    var3  combined_var3
# 4  1353.974749  229.855027  7.0     East    combined    var3  combined_var3

# %% [markdown]
# # Get paiwise correlations

# %%
df_sub = df[(df["SITE_ID"] == "ML") & (df["trait"] == "Height")].reset_index(drop=True)
df_sub.head()
# Out:
#     sample SITE_ID    offset    marker   trait POP_SITE  POP_ID   SET  \
# 0  1329_ML      ML  0.023707  1000var5  Height  1329_ML    1329  TEST
# 1  1528_ML      ML  0.027851  1000var5  Height  1528_ML    1528  TEST
# 2  1530_ML      ML  0.045286  1000var5  Height  1530_ML    1530  TEST
# 3  1531_ML      ML  0.025615  1000var5  Height  1531_ML    1531  TEST
# 4  1534_ML      ML  0.017506  1000var5  Height  1534_ML    1534  TEST
#
#           mean          sd    n group train_group climate     train_clim
# 0  1435.746514  165.025251  3.0  East    combined    var3  combined_var3
# 1  1424.030354   75.498344  3.0  East    combined    var3  combined_var3
# 2   976.829721  155.349069  3.0  East    combined    var3  combined_var3
# 3  1186.591020  130.000000  3.0  East    combined    var3  combined_var3
# 4  1367.178745  110.151411  3.0  East    combined    var3  combined_var3

# %%
factors = df["train_clim"].unique()
pairs = list(itertools.combinations(factors, 2))
fpairs = [ele for ele in pairs if ("var3" in ele[0]) & ("PC3" in ele[1])]
fpairs
# Out:
# [('combined_var3', 'combined_PC3'),
#  ('combined_var3', 'Central_PC3'),
#  ('combined_var3', 'West_PC3'),
#  ('combined_var3', 'East_PC3'),
#  ('Central_var3', 'combined_PC3'),
#  ('Central_var3', 'Central_PC3'),
#  ('Central_var3', 'West_PC3'),
#  ('Central_var3', 'East_PC3'),
#  ('West_var3', 'combined_PC3'),
#  ('West_var3', 'Central_PC3'),
#  ('West_var3', 'West_PC3'),
#  ('West_var3', 'East_PC3'),
#  ('East_var3', 'combined_PC3'),
#  ('East_var3', 'Central_PC3'),
#  ('East_var3', 'West_PC3'),
#  ('East_var3', 'East_PC3')]

# %%
# Get all unique factors and their pairwise combinations

def get_pearsons_corr(dataset):
    factors = dataset["train_clim"].unique()
    pairs = list(itertools.combinations(factors, 2))
    fpairs = [ele for ele in pairs if ("var3" in ele[0]) & ("PC3" in ele[1])]
    
    results = []
    
    for f1, f2 in fpairs:
        v1 = dataset.loc[dataset["train_clim"] == f1, "offset"].values
        v2 = dataset.loc[dataset["train_clim"] == f2, "offset"].values
    
        # Only compare if both have the same number of observations
        n = min(len(v1), len(v2))
        rho, pval = pearsonr(v1[:n], v2[:n])
        rho, pval = pearsonr(v1, v2)
        results.append({"train_clim1": f1, "train_clim2": f2, "r": rho, "p": pval, "n" : n})
    
    pairwise_corr = pd.DataFrame(results)
    return(pairwise_corr)

# %%
get_pearsons_corr(df_sub)
# Out:
# /tmp/ipykernel_803/921156722.py:16: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1[:n], v2[:n])
# /tmp/ipykernel_803/921156722.py:17: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1, v2)
#      train_clim1   train_clim2         r         p   n
# 0  combined_var3  combined_PC3  0.601759  0.000554  29
# 1  combined_var3   Central_PC3       NaN       NaN  29
# 2   Central_var3  combined_PC3  0.303175  0.109883  29
# 3   Central_var3   Central_PC3       NaN       NaN  29

# %% [markdown]
# # Loop

# %%
R = []
for site in ["PR","ML","CH","AC"]:
    for trait in df['trait'].drop_duplicates().values:
        df_sub = df[(df["SITE_ID"] == site) & (df["trait"] == trait)].reset_index(drop=True)

        df_corrs = get_pearsons_corr(df_sub)
        df_corrs['SITE_ID'] = site
        df_corrs['trait'] = trait
        R.append(df_corrs)
dR = pd.concat(R, ignore_index=True)
dR.head()
# Out:
# /tmp/ipykernel_803/921156722.py:16: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1[:n], v2[:n])
# /tmp/ipykernel_803/921156722.py:17: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1, v2)
# /tmp/ipykernel_803/921156722.py:16: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1[:n], v2[:n])
# /tmp/ipykernel_803/921156722.py:17: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1, v2)
# /tmp/ipykernel_803/921156722.py:16: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1[:n], v2[:n])
# /tmp/ipykernel_803/921156722.py:17: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1, v2)
# /tmp/ipykernel_803/921156722.py:16: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1[:n], v2[:n])
# /tmp/ipykernel_803/921156722.py:17: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1, v2)
# /tmp/ipykernel_803/921156722.py:16: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1[:n], v2[:n])
# /tmp/ipykernel_803/921156722.py:17: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1, v2)
# /tmp/ipykernel_803/921156722.py:16: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1[:n], v2[:n])
# /tmp/ipykernel_803/921156722.py:17: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1, v2)
# /tmp/ipykernel_803/921156722.py:16: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1[:n], v2[:n])
# /tmp/ipykernel_803/921156722.py:17: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1, v2)
# /tmp/ipykernel_803/921156722.py:16: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1[:n], v2[:n])
# /tmp/ipykernel_803/921156722.py:17: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1, v2)
# /tmp/ipykernel_803/921156722.py:16: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1[:n], v2[:n])
# /tmp/ipykernel_803/921156722.py:17: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1, v2)
# /tmp/ipykernel_803/921156722.py:16: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1[:n], v2[:n])
# /tmp/ipykernel_803/921156722.py:17: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1, v2)
# /tmp/ipykernel_803/921156722.py:16: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1[:n], v2[:n])
# /tmp/ipykernel_803/921156722.py:17: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1, v2)
# /tmp/ipykernel_803/921156722.py:16: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1[:n], v2[:n])
# /tmp/ipykernel_803/921156722.py:17: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1, v2)
# /tmp/ipykernel_803/921156722.py:16: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1[:n], v2[:n])
# /tmp/ipykernel_803/921156722.py:17: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1, v2)
# /tmp/ipykernel_803/921156722.py:16: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1[:n], v2[:n])
# /tmp/ipykernel_803/921156722.py:17: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1, v2)
# /tmp/ipykernel_803/921156722.py:16: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1[:n], v2[:n])
# /tmp/ipykernel_803/921156722.py:17: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1, v2)
# /tmp/ipykernel_803/921156722.py:16: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1[:n], v2[:n])
# /tmp/ipykernel_803/921156722.py:17: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1, v2)
# /tmp/ipykernel_803/921156722.py:16: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1[:n], v2[:n])
# /tmp/ipykernel_803/921156722.py:17: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1, v2)
# /tmp/ipykernel_803/921156722.py:16: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1[:n], v2[:n])
# /tmp/ipykernel_803/921156722.py:17: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1, v2)
# /tmp/ipykernel_803/921156722.py:16: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1[:n], v2[:n])
# /tmp/ipykernel_803/921156722.py:17: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1, v2)
# /tmp/ipykernel_803/921156722.py:16: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1[:n], v2[:n])
# /tmp/ipykernel_803/921156722.py:17: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1, v2)
# /tmp/ipykernel_803/921156722.py:16: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1[:n], v2[:n])
# /tmp/ipykernel_803/921156722.py:17: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1, v2)
# /tmp/ipykernel_803/921156722.py:16: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1[:n], v2[:n])
# /tmp/ipykernel_803/921156722.py:17: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1, v2)
# /tmp/ipykernel_803/921156722.py:16: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1[:n], v2[:n])
# /tmp/ipykernel_803/921156722.py:17: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1, v2)
# /tmp/ipykernel_803/921156722.py:16: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1[:n], v2[:n])
# /tmp/ipykernel_803/921156722.py:17: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1, v2)
# /tmp/ipykernel_803/921156722.py:16: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1[:n], v2[:n])
# /tmp/ipykernel_803/921156722.py:17: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1, v2)
# /tmp/ipykernel_803/921156722.py:16: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1[:n], v2[:n])
# /tmp/ipykernel_803/921156722.py:17: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = pearsonr(v1, v2)
#      train_clim1   train_clim2         r         p     n SITE_ID   trait
# 0  combined_var3  combined_PC3  0.753585  0.000009  26.0      PR  Height
# 1  combined_var3   Central_PC3  0.563227  0.002736  26.0      PR  Height
# 2  combined_var3      West_PC3  0.680302  0.000131  26.0      PR  Height
# 3   Central_var3  combined_PC3  0.684931  0.000113  26.0      PR  Height
# 4   Central_var3   Central_PC3  0.648019  0.000344  26.0      PR  Height

# %% [markdown]
# ### Saving

# %%
dR.to_csv("26_compare_offsets_between_climates.tsv", sep="\t", header=True, index=False)
