# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import glob
from scipy.stats import spearmanr
from statsmodels.stats.multitest import multipletests
import os

# %% [markdown]
# # TEST phenotypes

# %%
dpheno = pd.read_csv("../44_train_and_test/00_combine_samples_means.tsv", sep="\t", header=0)
dpheno = dpheno[dpheno['SET'] == 'TEST'].reset_index(drop=True)
print(dpheno["POP_SITE"].drop_duplicates().shape)
print(dpheno.shape)
dpheno["sample"] = dpheno["POP_SITE"]
dpheno.head()
# Out:
# (143,)
# (2048, 8)
#              Trait_name POP_SITE  POP_ID SITE_ID   SET        mean  \
# 0  Average_Ring_Density  1329_CH    1329      CH  TEST  476.575417
# 1  Average_Ring_Density  1329_ML    1329      ML  TEST  480.010872
# 2  Average_Ring_Density  1528_ML    1528      ML  TEST  514.502734
# 3  Average_Ring_Density  1530_AC    1530      AC  TEST  553.321396
# 4  Average_Ring_Density  1530_CH    1530      CH  TEST  526.616667
#
#            sd   n   sample
# 0   45.597986   8  1329_CH
# 1  108.572664   3  1329_ML
# 2   62.179284   3  1528_ML
# 3   48.783433  14  1530_AC
# 4   93.195567   6  1530_CH

# %%
dpheno[dpheno["n"] < 3].shape
# Out:
# (48, 9)

# %% [markdown]
# ### Filtering out rows (pop_site x trait ) which have means obtained from less than 3 samples

# %%
dpheno = dpheno[dpheno['n']>2].reset_index(drop=True)
print(dpheno["POP_SITE"].drop_duplicates().shape)
print(dpheno.shape)
# Out:
# (142,)
# (2000, 9)

# %% [markdown]
# # TRAIN phenotypes

# %%
tpheno = pd.read_csv("../44_train_and_test/00_combine_samples_means.tsv", sep="\t", header=0)
tpheno = tpheno[tpheno['SET'] == 'TRAIN'].reset_index(drop=True)
print(tpheno["POP_SITE"].drop_duplicates().shape)
print(tpheno.shape)
tpheno["sample"] = tpheno["POP_SITE"]

print(tpheno[tpheno["n"] < 3].shape)

### Filtering out rows (pop_site x trait ) which have means obtained from less than 3 samples
tpheno = tpheno[tpheno['n']>2].reset_index(drop=True)
print(tpheno["POP_SITE"].drop_duplicates().shape)
print(tpheno.shape)
# Out:
# (115,)
# (1738, 8)
# (108, 9)
# (115,)
# (1630, 9)

# %% [markdown]
# # Combining genetic offset sets

# %% [markdown]
# This is a list of all pop_sites x traits for which offsets were calculated, should correspond to the list in the TEST

# %%
traits = ["Height", "Biomass_Increment", "Biomass_Increment_1980", "Biomass_Increment_1985", 
                "Biomass_Increment_1990", "Biomass_Increment_1995", "Biomass_Increment_2000", 
                "Biomass_Increment_2005", "Biomass_Increment_2010", "Biomass_Increment_2015",
                "Average_Ring_Density", "DBH", "Rs", "Rl", "Rr","Rc"]

gardens = ["PR","ML","CH","AC"]


dsets = ["100","100LF","1000","1000LF","10000","all","lfmm","RDA","RDAcorrected"]
#dsets = ["100","100LF","1000","1000LF","10000","lfmm","RDA","RDAcorrected"]
dsets
# Out:
# ['100',
#  '100LF',
#  '1000',
#  '1000LF',
#  '10000',
#  'all',
#  'lfmm',
#  'RDA',
#  'RDAcorrected']

# %%
D = []

for trait in traits:
    for dset in dsets:
        for garden in gardens:
            file_path = "../991_run_rda_separate/results/01_run_gradient_forest_" + garden + "_" + dset + "_" + trait + ".tsv"
            if os.path.exists(file_path):
                df_ = pd.read_csv(file_path, sep="\t", header=0)
                df_["marker"] = dset
                df_["trait"] = trait
                df_["garden"] = garden
                D.append(df_)
dD = pd.concat(D)
print(dD.shape)
dD.head()
# Out:
# (18171, 17)
#   Trait_name   sample SITE_ID    group        PC1       PC2       PC3  \
# 0     Height  2209_PR      PR     West  12.351204 -1.598833  0.851360
# 1     Height   325_PR      PR  Central   2.506557 -3.166880  1.958590
# 2     Height  4351_PR      PR  Central  -6.244846  1.531312 -1.399408
# 3     Height  4420_PR      PR     West   6.170760  3.960606 -2.183338
# 4     Height  6805_PR      PR     East   0.111999 -2.575310  0.678848
#
#     now_at1   now_at2   now_at3   new_at1   new_at2   new_at3  offset_rda  \
# 0 -0.137404  0.008320 -0.034849 -0.092504  0.022562  0.011815    0.066306
# 1  0.216062  0.025052 -0.015024 -0.092504  0.022562  0.011815    0.309741
# 2  0.070104  0.017961  0.031062 -0.092504  0.022562  0.011815    0.163807
# 3 -0.329745 -0.015507  0.002304 -0.092504  0.022562  0.011815    0.240465
# 4  0.155253  0.035445 -0.000285 -0.092504  0.022562  0.011815    0.248386
#
#   marker   trait garden
# 0    100  Height     PR
# 1    100  Height     PR
# 2    100  Height     PR
# 3    100  Height     PR
# 4    100  Height     PR

# %%
# List of pop_sites x traits = 141 - two missing (?)
dD_sub = dD[["sample","SITE_ID","offset_rda","marker","trait"]].reset_index(drop=True)
print(dD_sub["sample"].drop_duplicates().shape)
print(dD_sub.shape)
dD_sub.head()
# Out:
# (141,)
# (18171, 5)
#     sample SITE_ID  offset_rda marker   trait
# 0  2209_PR      PR    0.066306    100  Height
# 1   325_PR      PR    0.309741    100  Height
# 2  4351_PR      PR    0.163807    100  Height
# 3  4420_PR      PR    0.240465    100  Height
# 4  6805_PR      PR    0.248386    100  Height

# %% [markdown]
# ### Test

# %%
dD_merge = pd.merge(dD_sub, dpheno, left_on = ["sample","SITE_ID","trait"], right_on = ["sample","SITE_ID","Trait_name"], how = "left")
print(dD_merge.shape)
dD_merge.head()

# There are rows with missing information - these are generally pop_sites x traits where phenotypes were measured on less than 3 samples  
# Removing these
dD_merge.loc[dD_merge["SET"].isna(),['sample']].drop_duplicates().shape
dD_merge.loc[dD_merge["SET"].isna(),['sample']].drop_duplicates()

dD_merge = dD_merge.dropna().reset_index(drop=True)
print(dD_merge.shape)
# Out:
# (18171, 12)
# (17748, 12)

# %%
print(dD_merge["sample"].drop_duplicates().shape)
# Out:
# (140,)

# %% [markdown]
# ### Train

# %%
tD_merge = pd.merge(dD_sub, tpheno, left_on = ["sample","SITE_ID","trait"], right_on = ["sample","SITE_ID","Trait_name"], how = "left")
print(tD_merge.shape)
tD_merge.head()

tD_merge = tD_merge.dropna().reset_index(drop=True)
print(tD_merge.shape)
#tD_merge[tD_merge["SET"].isna()]
tD_merge.head()
# Out:
# (18171, 12)
# (14625, 12)
#     sample SITE_ID  offset_rda marker   trait Trait_name POP_SITE  POP_ID  \
# 0  2209_PR      PR    0.066306    100  Height     Height  2209_PR  2209.0
# 1   325_PR      PR    0.309741    100  Height     Height   325_PR   325.0
# 2  4351_PR      PR    0.163807    100  Height     Height  4351_PR  4351.0
# 3  4420_PR      PR    0.240465    100  Height     Height  4420_PR  4420.0
# 4  6805_PR      PR    0.248386    100  Height     Height  6805_PR  6805.0
#
#      SET         mean          sd     n
# 0  TRAIN   909.275258  298.708530   8.0
# 1  TRAIN  1202.391145  197.315314   7.0
# 2  TRAIN  1311.931938  178.648122  12.0
# 3  TRAIN   732.439612  171.158517   7.0
# 4  TRAIN  1277.611112  147.869722  11.0

# %%
df_combo = pd.concat([dD_merge, tD_merge], ignore_index=True)
df_combo.head()
print(df_combo.shape)
df_combo[df_combo['SET'].isna()]
df_combo[df_combo['POP_ID'].isna()]
# Out:
# (32373, 12)
# Empty DataFrame
# Columns: [sample, SITE_ID, offset_rda, marker, trait, Trait_name, POP_SITE, POP_ID, SET, mean, sd, n]
# Index: []

# %%
df_combo["POP_ID"] = df_combo["POP_ID"].astype(int).astype(str)
df_combo["POP_ID"]
# Out:
# 0        2209
# 1         325
# 2        4351
# 3        4420
# 4        6805
#          ...
# 32368    4277
# 32369    4351
# 32370    6941
# 32371    6969
# 32372    6983
# Name: POP_ID, Length: 32373, dtype: object

# %% [markdown]
# ## Adding group

# %% [markdown]
# Some pops do not have assigned groups : 6944 and 6937

# %%
dgroup = pd.read_csv("../DATA_intermediate/23_filter_clean_indiv_metrics.tsv", sep="\t", header=0)
dgroup["POP_ID"] = dgroup["POP"].astype(str).astype("object")
dgroup = dgroup[["POP_ID","group"]].drop_duplicates().reset_index(drop=True)
print(dgroup.shape)
dgroup.head()

add = pd.DataFrame({"POP_ID" : ["6937","6944"],
                   "group" : ["Central","Central"]})
#dgroup["POP_ID"].values
mgroup = pd.concat([dgroup, add], ignore_index=True)
print(mgroup.shape)
mgroup.tail()

#mgroup.to_csv("../METADATA/populations_genetic_groups.tsv", sep="\t", header=True, index=False)
# Out:
# (80, 2)
# (82, 2)
#    POP_ID    group
# 77   6969     West
# 78    995     West
# 79   7003     West
# 80   6937  Central
# 81   6944  Central

# %%
dm_combo = pd.merge(df_combo, mgroup, on = "POP_ID", how = "left")
dm_combo.head()
# Out:
#     sample SITE_ID  offset_rda marker   trait Trait_name POP_SITE POP_ID  \
# 0  2209_PR      PR    0.066306    100  Height     Height  2209_PR   2209
# 1   325_PR      PR    0.309741    100  Height     Height   325_PR    325
# 2  4351_PR      PR    0.163807    100  Height     Height  4351_PR   4351
# 3  4420_PR      PR    0.240465    100  Height     Height  4420_PR   4420
# 4  6805_PR      PR    0.248386    100  Height     Height  6805_PR   6805
#
#     SET         mean          sd    n    group
# 0  TEST   980.525258  302.158899  4.0     West
# 1  TEST  1239.891145  121.743290  8.0  Central
# 2  TEST  1423.598605   68.068593  4.0  Central
# 3  TEST   678.153897  154.272486  7.0     West
# 4  TEST  1353.974749  229.855027  7.0     East

# %%
dm_combo.loc[dm_combo["group"].isna(),'sample'].drop_duplicates()
# Out:
# Series([], Name: sample, dtype: object)

# %% [markdown]
# ### Removing WI and ME

# %%
dc_combo = dm_combo[~dm_combo['group'].isin(["WI","ME"])].reset_index(drop=True)
print(dc_combo.shape)
# Out:
# (31311, 13)

# %%
dc_combo.to_csv("01B_garden_compare_rda.tsv", sep = "\t", header=True, index=False)

# %% [markdown]
# # END
